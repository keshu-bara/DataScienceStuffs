# %% [markdown]
# # Vectors

# %% [markdown]
# Simple represting data as like vectors like have height weight age and represting them in 3D

# %%
height_weight_age = [70, #inches, v1
                     170, #pounds v2
                     40 ] # years, v3
grades = [ 95, # exam1
           80, # exam2
           70, # exam3
           69, # exam4
           20, # exam5
         ]

# %%
# represting vectors

v1 = [0 , 0]
v2 = [1 , 2]
v3 = [3 , 3]

import matplotlib.pyplot as plt

plt.plot([x for x in [v1[0],v2[0],v3[0]]],[y for y in [v1[1], v2[1], v3[1]]],color = 'red', marker = 'o')
plt.plot([0,3],[0,3],'r-.')
plt.axis([-5,5,-5,5])
plt.show()
